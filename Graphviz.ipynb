# %%
# !pip install graphviz

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:\Program Files\Graphviz/bin/'

# %%
import graphviz
from graphviz import Digraph

# %%
dot = graphviz.Digraph(comment='Структура математики')
dot.node('A', 'Математика')
dot.node('B', 'Арифметика')
dot.node('C', 'Геометрия')
dot.node('D', 'Статистика')
dot.node('E', 'Множества')

dot.edges(['AB', 'AC', 'AD', 'AE'])

dot.node('F', 'Алгебра')
dot.node('G', 'Математическая логика') 
dot.node('H', 'Математический анализ')
dot.node('I', 'Топология')
dot.node('J', 'Тригонометрия')
dot.node('K', 'Теория вероятностей')
dot.node('L', 'Комбинаторика')
dot.node('M', 'Функции')
dot.node('N', 'Векторы')

dot.edges(['BF', 'BG', 'BH'])
dot.edges(['CI', 'CJ'])
dot.edges(['DK', 'DL'])
dot.edges(['EM', 'EN'])


dot
# Out:
# [DEBUG@graphviz.backend] run ['dot', '-Kdot', '-Tsvg']

# %%
dot = graphviz.Digraph(comment='Исследование функции с помощью производной')
dot.node('A', 'Производная')
dot.node('B', 'Первая')
dot.node('C', 'Вторая')

dot.edges(['AB', 'AC'])

dot.node('D', 'Найди точки, в которых производная равна 0\n или не существует')
dot.node('M', 'Найди точки, в которых производная равна 0\n или не существует')

dot.edges(['BD', 'CM'])

dot.node('E', shape='diamond', label= 'Как производная меняет знак?') 
dot.node('F', 'С + на -')
dot.node('G', 'С - на +')



dot.edges(['DE', 'MH', 'EF', 'EG'])

dot.node('H', 'Точка перегиба')


dot.node('K', 'Точка локального максимума')
dot.node('L', 'Точка локального минимума')
dot.edges(['FK', 'GL'])

dot
# Out:
# [DEBUG@graphviz.backend] run ['dot', '-Kdot', '-Tsvg']

# %%
dot = graphviz.Digraph(comment='Спектр')
dot.node('A', 'Спектр видимого света')
dot.node('B', 'Длина волны')
dot.node('C', '625-740 нм')
dot.node('D', '590-625 нм')
dot.node('E', '565-590 нм')
dot.node('F', '500-565 нм')
dot.node('G', '485-500 нм')
dot.node('H', '440-485 нм') 
dot.node('I', '380-440 нм')

dot.edges(['AB', 'BC', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI',])

dot.node('J', color='red', style='filled', label='Красный')
dot.node('K', color='orange', style='filled', label='Оранжевый')
dot.node('L', color='yellow', style='filled', label='Желтый')
dot.node('M', color='green', style='filled', label='Зеленый')
dot.node('N', color='lightblue', style='filled', label='Голубой')
dot.node('O', color='blue', style='filled', label='Синий')
dot.node('P', color='purple', style='filled', label='Фиолетовый')

dot.edges(['CJ', 'DK', 'EL', 'FM', 'GN', 'HO', 'IP'])

dot
# Out:
# [DEBUG@graphviz.backend] run ['dot', '-Kdot', '-Tsvg']

# %%
dot = graphviz.Digraph(comment='Цикл Кребса')
dot.node('A', 'Пируват')
dot.node('B', 'Ацетил-КоА')
dot.node('C', 'Цитрат')
dot.node('D', 'Изоцитрат')
dot.node('E', 'Альфа-кетоглутарат')
dot.node('F', 'Сукцинил-КоА')
dot.node('G', 'Сукцинат')
dot.node('H', 'Фумарат') 
dot.node('I', 'Малат')
dot.node('I', 'Оксалоацетат')

dot.edges(['AB', 'BC', 'CD', 'DE', 'EF', 'FG', 'GH', 'HI', 'IC'])
dot.engine ='circo'
dot
# Out:
# [DEBUG@graphviz.backend] run ['dot', '-Kcirco', '-Tsvg']

# %%
dot = graphviz.Digraph(comment='Метилоранж')
d.attr(rankdir='LB')
dot.node('A', shape='rectangle', label='Окраска\n в разных средах')
dot.node('B', shape='rectangle', label='Кислая среда')
dot.node('C', shape='rectangle', label='pH<7')
dot.node('D', shape='rectangle', label='Нейтральная среда')
dot.node('E', shape='rectangle', label='pH=7')
dot.node('F', shape='rectangle', label='Щелочная среда')
dot.node('G', shape='rectangle', label='pH>7')
dot.node('I',  shape='rectangle', label='Метилоранж')
dot.node('H',  shape='rectangle', image='Methyl-orange-2D-skeletal.png')
dot.edges(['HI'])
dot.edges(['IA','AB', 'AD', 'AF', 'BC', 'DE', 'FG'])
dot.node('J', color='red', shape='rectangle', style='filled', label='Красный')
dot.node('K', color='orange', shape='rectangle', style='filled', label='Оранжевый')
dot.node('L', color='yellow', shape='rectangle', style='filled', label='Желтый')
dot.edges(['CJ','EK', 'GL'])
dot
# Out:
# [DEBUG@graphviz.backend] run ['dot', '-Kdot', '-Tsvg']
